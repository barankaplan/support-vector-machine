# %%
import numpy as np 
import pandas as pd

# %%
wine = pd.read_csv("winequality-red.csv")
df = wine.copy()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
df.T
# Out:
#                          0        1       2       3        4        5     \
# fixed acidity          7.4000   7.8000   7.800  11.200   7.4000   7.4000
# volatile acidity       0.7000   0.8800   0.760   0.280   0.7000   0.6600
# citric acid            0.0000   0.0000   0.040   0.560   0.0000   0.0000
# residual sugar         1.9000   2.6000   2.300   1.900   1.9000   1.8000
# chlorides              0.0760   0.0980   0.092   0.075   0.0760   0.0750
# free sulfur dioxide   11.0000  25.0000  15.000  17.000  11.0000  13.0000
# total sulfur dioxide  34.0000  67.0000  54.000  60.000  34.0000  40.0000
# density                0.9978   0.9968   0.997   0.998   0.9978   0.9978
# pH                     3.5100   3.2000   3.260   3.160   3.5100   3.5100
# sulphates              0.5600   0.6800   0.650   0.580   0.5600   0.5600
# alcohol                9.4000   9.8000   9.800   9.800   9.4000   9.4000
# quality                5.0000   5.0000   5.000   6.000   5.0000   5.0000
#
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df.describe([0.05,0.10,0.25,0.50,0.75,0.80,0.90,0.95,0.99]).T
# Out:
#                        count       mean        std      min         5%  \
# fixed acidity         1599.0   8.319637   1.741096  4.60000   6.100000
# volatile acidity      1599.0   0.527821   0.179060  0.12000   0.270000
# citric acid           1599.0   0.270976   0.194801  0.00000   0.000000
# residual sugar        1599.0   2.538806   1.409928  0.90000   1.590000
# chlorides             1599.0   0.087467   0.047065  0.01200   0.054000
# free sulfur dioxide   1599.0  15.874922  10.460157  1.00000   4.000000
# total sulfur dioxide  1599.0  46.467792  32.895324  6.00000  11.000000
# density               1599.0   0.996747   0.001887  0.99007   0.993598
# pH                    1599.0   3.311113   0.154386  2.74000   3.060000
# sulphates             1599.0   0.658149   0.169507  0.33000   0.470000
# alcohol               1599.0  10.422983   1.065668  8.40000   9.200000
# quality               1599.0   5.636023   0.807569  3.00000   5.000000
#
# ...

# %%
#sns.pairplot(df,diag_kind='kde',markers="+")

# %%
correlation_matrix = df.corr().round(2) 
figure = plt.figure(figsize=(12, 12))
sns.heatmap(data=correlation_matrix, annot=True)

# %%
def lmplot_function(data,x_att,y_att,hue_att,my_filter):
    sns.lmplot(x =x_att, y =y_att, hue = hue_att,data = df)
    plt.show()
    val=np.unique(np.array(df[my_filter]))
    for x in val:
      sns.lmplot(x =x_att, y =y_att, hue = hue_att,
          data = df[df['quality']==x])

# %%
lmplot_function(df,"alcohol","sulphates","quality","quality")

# %%
plt.figure()
sns.countplot(df['quality'])

# %%
df.quality.unique()
# Out:
# array([5, 6, 7, 4, 8, 3])

# %%
df.nunique()
# Out:
# fixed acidity            96
# volatile acidity        143
# citric acid              80
# residual sugar           91
# chlorides               153
# free sulfur dioxide      60
# total sulfur dioxide    144
# density                 436
# pH                       89
# sulphates                96
# alcohol                  65
# quality                   6
# dtype: int64

# %%
df.quality.value_counts()
# Out:
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: quality, dtype: int64

# %%
#categorize wine quality
bins = (2,5.5,8)
group_names = ['bad','good']
categories = pd.cut(df['quality'], bins, labels = group_names)
df['quality'] = categories

# %%
df.quality.value_counts()
# Out:
# good    855
# bad     744
# Name: quality, dtype: int64

# %%
#df=df.loc[(df['quality'] == 5) | (df['quality'] == 6) ]

# %%
#df=df.loc[(df['quality'] == 5) | (df['quality'] == 6) | (df['quality'] == 7)]

# %%
#def find_skewed_boundaries(df, variable, distance):

    # Let's calculate the boundaries outside which sit the outliers
    # for skewed distributions

    # distance passed as an argument, gives us the option to
    # estimate 1.5 times or 3 times the IQR to calculate
    # the boundaries.

    #IQR = df[variable].quantile(0.75) - df[variable].quantile(0.25)

    #lower_boundary = df[variable].quantile(0.25) - (IQR * distance)
    #upper_boundary = df[variable].quantile(0.75) + (IQR * distance)

    #return upper_boundary, lower_boundary

# %% [markdown]
# upper_boundary, lower_boundary = find_skewed_boundaries(df, 'quality', 1.5)
# upper_boundary, lower_boundary

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   category
# dtypes: category(1), float64(11)
# memory usage: 139.2 KB

# %% [markdown]
# Q1 = df.quality.quantile(0.25)
# Q3 = df.quality.quantile(0.75)
# IQR = Q3-Q1
# lower = Q1 - 1.5*IQR
# upper = Q3 + 1.5*IQR
# df=df.loc[(df["quality"] < upper)&(df["quality"] > lower)]

# %%
df.reset_index(drop=True)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   category
# dtypes: category(1), float64(11)
# memory usage: 139.2 KB

# %%
df[df.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [fixed acidity, volatile acidity, citric acid, residual sugar, chlorides, free sulfur dioxide, total sulfur dioxide, density, pH, sulphates, alcohol, quality]
# Index: []

# %%
df.describe([0.05,0.10,0.25,0.50,0.75,0.80,0.90,0.95,0.99]).T
# Out:
#                        count       mean        std      min         5%  \
# fixed acidity         1599.0   8.319637   1.741096  4.60000   6.100000
# volatile acidity      1599.0   0.527821   0.179060  0.12000   0.270000
# citric acid           1599.0   0.270976   0.194801  0.00000   0.000000
# residual sugar        1599.0   2.538806   1.409928  0.90000   1.590000
# chlorides             1599.0   0.087467   0.047065  0.01200   0.054000
# free sulfur dioxide   1599.0  15.874922  10.460157  1.00000   4.000000
# total sulfur dioxide  1599.0  46.467792  32.895324  6.00000  11.000000
# density               1599.0   0.996747   0.001887  0.99007   0.993598
# pH                    1599.0   3.311113   0.154386  2.74000   3.060000
# sulphates             1599.0   0.658149   0.169507  0.33000   0.470000
# alcohol               1599.0  10.422983   1.065668  8.40000   9.200000
#
#                             10%      25%       50%        75%        80%  \
# ...

# %%
from sklearn.neighbors import LocalOutlierFactor

# %%
y=df['quality']
x=df.drop(['quality'], axis=1, inplace=False)
columns=x.columns.tolist()
clf = LocalOutlierFactor(n_neighbors=20, contamination=0.1)
y_pred=clf.fit_predict(x)

# %%
y_pred
y_inlier= np.count_nonzero(y_pred == -1)
y_inlier  #outlier olmayanlar inlier
# Out:
# 160

# %%
X_score=clf.negative_outlier_factor_
outlier_score=pd.DataFrame()
outlier_score['score']=X_score
with pd.option_context("display.max_rows", 100):
    display(outlier_score.sort_values(by='score', ascending=True))
# Out:
#          score
# 1081 -8.900810
# 1079 -8.271898
# 480  -3.355883
# 1244 -2.460958
# 325  -2.050708
# ...        ...
# 1504 -0.961579
# 822  -0.960094
# 823  -0.960094
# 159  -0.959659
# 134  -0.956105
#
# [1599 rows x 1 columns]

# %%
threshold=-3.355883
filtre=outlier_score['score']<threshold
outlier_index=outlier_score[filtre].index.tolist()

# %%
plt.figure()
plt.scatter(x.iloc[outlier_index,0],x.iloc[outlier_index,1],color='blue',s=300,label='Outliers')
plt.scatter(x.iloc[:,0],x.iloc[:,1],color='k',s=3,label='Data Points')

radius=(X_score.max()-X_score)/(X_score.max()-X_score.min())
outlier_score['radius']=radius
plt.scatter(x.iloc[:,0],x.iloc[:,1],s=1000*radius,edgecolors='r',facecolors='none',label='Outlier Scores')
plt.legend()
plt.rcParams['figure.figsize'] = (45.0, 45.0)
plt.show()

# %%
x=x.drop(outlier_index)

y=y.drop(outlier_index)

# %%
data=x
data['quality'] = y

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1597 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1597 non-null   float64
#  1   volatile acidity      1597 non-null   float64
#  2   citric acid           1597 non-null   float64
#  3   residual sugar        1597 non-null   float64
#  4   chlorides             1597 non-null   float64
#  5   free sulfur dioxide   1597 non-null   float64
#  6   total sulfur dioxide  1597 non-null   float64
#  7   density               1597 non-null   float64
#  8   pH                    1597 non-null   float64
#  9   sulphates             1597 non-null   float64
#  10  alcohol               1597 non-null   float64
#  11  quality               1597 non-null   category
# dtypes: category(1), float64(11)
# memory usage: 151.4 KB

# %%
df=data.copy()

# %%
# function to create histogram, Q-Q plot and
# boxplot. We learned this in section 3 of the course


def diagnostic_plots(df, variable):
    # function takes a dataframe (df) and
    # the variable of interest as arguments

    # define figure size
    plt.figure(figsize=(16, 4))

    # histogram
    plt.subplot(1, 3, 1)
    sns.distplot(df[variable], bins=30)
    plt.title('Histogram')

    # Q-Q plot
    plt.subplot(1, 3, 2)
    stats.probplot(df[variable], dist="norm", plot=plt)
    plt.ylabel('RM quantiles')

    # boxplot
    plt.subplot(1, 3, 3)
    sns.boxplot(y=df[variable])
    plt.title('Boxplot')

    plt.show()

# %%
def find_boundaries(df, variable):

    # the boundaries are the quantiles

    lower_boundary = df[variable].quantile(0.05)
    upper_boundary = df[variable].quantile(0.95)

    return upper_boundary, lower_boundary

# %%
import scipy.stats as stats

# %%
diagnostic_plots(df, 'residual sugar')

# %%
RM_upper_limit, RM_lower_limit = find_boundaries(df, 'residual sugar')
RM_upper_limit, RM_lower_limit
# Out:
# (5.1, 1.5800000000000012)

# %%
# Now let's replace the outliers by the maximum and minimum limit

df['residual sugar']= np.where(df['residual sugar'] > RM_upper_limit, RM_upper_limit,
                       np.where(df['residual sugar'] < RM_lower_limit, RM_lower_limit, df['residual sugar']))

# %% [markdown]
# diagnostic_plots(df, 'residual sugar')

# %%
diagnostic_plots(df, 'chlorides')

# %% [markdown]
# RM_upper_limit, RM_lower_limit = find_boundaries(df, 'chlorides')
# RM_upper_limit, RM_lower_limit

# %%
diagnostic_plots(df, 'residual sugar')

# %%
diagnostic_plots(df, 'chlorides')

# %%
RM_upper_limit, RM_lower_limit = find_boundaries(df, 'chlorides')
RM_upper_limit, RM_lower_limit
# Out:
# (0.1261999999999998, 0.054000000000000006)

# %%
# Now let's replace the outliers by the maximum and minimum limit

df['chlorides']= np.where(df['chlorides'] > RM_upper_limit, RM_upper_limit,
                       np.where(df['chlorides'] < RM_lower_limit, RM_lower_limit, df['chlorides']))

# %%
diagnostic_plots(df, 'chlorides')

# %%
diagnostic_plots(df, 'sulphates')

# %%
RM_upper_limit, RM_lower_limit = find_boundaries(df, 'sulphates')
RM_upper_limit, RM_lower_limit
# Out:
# (0.93, 0.47)

# %%
# Now let's replace the outliers by the maximum and minimum limit

df['sulphates']= np.where(df['sulphates'] > RM_upper_limit, RM_upper_limit,
                       np.where(df['sulphates'] < RM_lower_limit, RM_lower_limit, df['sulphates']))

# %%
diagnostic_plots(df, 'sulphates')

# %%
df.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00            1.90      0.076
# 1            7.8              0.88         0.00            2.60      0.098
# 2            7.8              0.76         0.04            2.30      0.092
# 3           11.2              0.28         0.56            1.90      0.075
# 4            7.4              0.70         0.00            1.90      0.076
# 5            7.4              0.66         0.00            1.80      0.075
# 6            7.9              0.60         0.06            1.60      0.069
# 7            7.3              0.65         0.00            1.58      0.065
# 8            7.8              0.58         0.02            2.00      0.073
# 9            7.5              0.50         0.36            5.10      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
data_pca=df.copy()

# %%
data_pca.drop('quality', inplace=True, axis=1)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=0.95, whiten=True)
from sklearn.preprocessing import StandardScaler
df_pca = StandardScaler().fit_transform(data_pca)
principalComponents = pca.fit_transform(data_pca)
print("Original number of features:", data_pca.shape[1]) 
print("Reduced number of features:", principalComponents.shape[1])
# Out:
# Original number of features: 11
# Reduced number of features: 2

# %%
import matplotlib.pyplot as plt

PC = range(1, pca.n_components_+1)
plt.bar(PC, pca.explained_variance_ratio_, color='gold')
plt.xlabel('Principal Components')
plt.ylabel('Variance %')
plt.xticks(PC)
# Out:
# ([<matplotlib.axis.XTick at 0x7fcf2217f040>,
# ...
#  <a list of 2 Text major ticklabel objects>)

# %%
df_pca = pd.DataFrame(principalComponents)

# %%
extracted_col = df["quality"]
  
df_pca = df_pca.join(extracted_col)

# %%
df_pca
# Out:
#              0         1 quality
# 0    -0.396549 -0.258057     bad
# 1     0.685470  0.553388     bad
# 2     0.227867 -0.345963     bad
# 3     0.420082 -0.279680    good
# 4    -0.396549 -0.258057     bad
# ...        ...       ...     ...
# 1592  0.048252  2.159696    good
# 1593  0.305827  2.855365    good
# 1594 -0.092095  1.893813     bad
# 1595  0.048378  2.159991    good
# 1596 -0.108944  0.412941    good
#
# [1597 rows x 3 columns]

# %%
X=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder_y = LabelEncoder()
y = labelencoder_y.fit_transform(y)
y
# Out:
# array([0, 0, 0, ..., 1, 0, 1])

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X)
X = scaler.transform(X)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
from sklearn.svm import SVC
from sklearn import metrics
svc = SVC(kernel='rbf')
svc.fit(X_train,y_train)
y_pred=svc.predict(X_test)
print('Accuracy Score:')
print(metrics.accuracy_score(y_test,y_pred))
# Out:
# Accuracy Score:
# 0.784375

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split

# %%
svc=SVC(kernel='rbf')
scores = cross_val_score(svc, X, y, cv=10, scoring='accuracy') #cv is cross validation
print(scores)
# Out:
# [0.6375     0.79375    0.71875    0.68125    0.725      0.8625
#  0.7625     0.74842767 0.74842767 0.69811321]

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[120  24]
#  [ 45 131]]
#               precision    recall  f1-score   support
#
#            0       0.73      0.83      0.78       144
#            1       0.85      0.74      0.79       176
#
#     accuracy                           0.78       320
#    macro avg       0.79      0.79      0.78       320
# weighted avg       0.79      0.78      0.78       320

# %%
import numpy as np
import matplotlib.pyplot as plt
from itertools import cycle

from sklearn import svm, datasets
from sklearn.metrics import roc_curve, auc
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import label_binarize
from sklearn.multiclass import OneVsRestClassifier
from scipy import interp

# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
fpr, tpr, _ = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)

# Compute micro-average ROC curve and ROC area
fpr, tpr, thresholds = metrics.roc_curve(y_test, y_pred, pos_label=1)
roc_auc = auc(fpr,tpr)

print(f"FPR: {fpr}")
print(f"TPR: {tpr}")
print(f"AUC: {roc_auc}")
print(f"thresholds: {thresholds}")
# Out:
# FPR: [0.         0.16666667 1.        ]
# TPR: [0.         0.74431818 1.        ]
# AUC: 0.7888257575757576
# thresholds: [2 1 0]

# %%
plt.figure()
lw = 2
plt.plot(fpr, tpr, color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# pip install polynomial-regression

# %% [markdown]
# from sklearn.preprocessing import PolynomialFeatures
# from sklearn.linear_model import LinearRegression
# from sklearn.pipeline import make_pipeline
# def PolynomialRegression(degree=2, **kwargs):
#     return make_pipeline(PolynomialFeatures(degree), LinearRegression(**kwargs))

# %% [markdown]
# import matplotlib.pyplot as plt
# import seaborn; seaborn.set() # plot formatting X_test = np.linspace(-0.1, 1.1, 500)[:, None]
# plt.scatter(X.ravel(), y, color='black') axis = plt.axis()
# for degree in [1, 3, 5]:
#                 y_test = PolynomialRegression(degree).fit(X, y).predict(X_test)
#                 plt.plot(X_test.ravel(), y_test, label='degree={0}'.format(degree))
#             plt.xlim(-0.1, 1.0)
#             plt.ylim(-2, 12)
#             plt.legend(loc='best');

# %% [markdown]
# from sklearn.model_selection import validation_curve
# from sklearn.preprocessing import PolynomialFeatures
# degree = np.arange(0, 21)
# train_score, val_score = validation_curve(PolynomialRegression(), X, y,
#                                               'polynomialfeatures__degree',
#                                               degree, cv=7)
# plt.plot(degree, np.median(train_score, 1), color='blue', label='training score')
# plt.plot(degree, np.median(val_score, 1), color='red', label='validation score')
# plt.legend(loc='best')
# plt.ylim(0, 1)
# plt.xlabel('degree')
# plt.ylabel('score');

# %%
X=df[['volatile acidity','alcohol']]
y=df.iloc[:,-1]

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder_y = LabelEncoder()
y = labelencoder_y.fit_transform(y)
y
# Out:
# array([0, 0, 0, ..., 1, 0, 1])

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X)
X = scaler.transform(X)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
from sklearn.svm import SVC
from sklearn import metrics
svclassifier = SVC(kernel='rbf')
svc.fit(X_train,y_train)
y_pred=svc.predict(X_test)
print('Accuracy Score:')
print(metrics.accuracy_score(y_test,y_pred))
# Out:
# Accuracy Score:
# 0.771875

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split

# %%
svc=SVC(kernel='rbf')
scores = cross_val_score(svc, X, y, cv=10, scoring='accuracy') 
print(scores)
# Out:
# [0.625      0.7625     0.76875    0.625      0.69375    0.875
#  0.75       0.71069182 0.74842767 0.71069182]

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[118  26]
#  [ 47 129]]
#               precision    recall  f1-score   support
#
#            0       0.72      0.82      0.76       144
#            1       0.83      0.73      0.78       176
#
#     accuracy                           0.77       320
#    macro avg       0.77      0.78      0.77       320
# weighted avg       0.78      0.77      0.77       320

# %%
from matplotlib.colors import ListedColormap
import matplotlib.pyplot as plt
from sklearn.svm import SVC
from sklearn import datasets
from sklearn.preprocessing import StandardScaler 
import numpy as np
    # Set randomization seed
np.random.seed(0)
# Generate two features
features = np.random.randn(200, 2)
# Use a XOR gate (you don't need to know what this is) to generate # linearly inseparable classes
target_xor = np.logical_xor(features[:, 0] > 0, features[:, 1] > 0 ) 
target = np.where(target_xor, 0, 1)
    # Create a support vector machine with a radial basis function kernel
svc = SVC(kernel="rbf", random_state=0, gamma=1, C=1) # Train the classifier
model = svc.fit(X_train,y_train)

# %%
svc_linear = SVC(kernel="linear", random_state=0, C=10)

# %%
svc_linear.fit(X_train,y_train)
# Out:
# SVC(C=10, kernel='linear', random_state=0)

# %%
plot_decision_regions(features, target, classifier=svc_linear)
plt.axis("off"), plt.show();
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
svc = SVC(kernel="rbf", random_state=0, gamma=50, C=300) # Train the classifier
model = svc.fit(X_train,y_train)

# %%
# Plot observations and hyperplane
plot_decision_regions(features, target, classifier=svc)
plt.axis("off"), plt.show();
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
